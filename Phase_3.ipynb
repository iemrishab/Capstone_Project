# %% [markdown]
# # Capstone Project

# %%
#Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data1=pd.read_csv('https://raw.githubusercontent.com/12345mayanksingh/model11/main/table111.csv')
data1
# Out:
#       Unnamed: 0.1  Unnamed: 0   sno     Brand_name  \
# 0                0           0     0   Chanda Khuba
# 1                1           1     1   Chanda Khuba
# 2                2           2     2  Swear Clothes
# 3                3           3     3  VALKO FASHION
# 4                4           4     4       PROTOCOL
# ...            ...         ...   ...            ...
# 3995          3995        3995  3995      Indi Hemp
# 3996          3996        3996  3996      Indi Hemp
# 3997          3997        3997  3997      Indi Hemp
# 3998          3998        3998  3998      Indi Hemp
# 3999          3999        3999  3999      Indi Hemp
#
#                                                Category  \
# 0               Men Full Sleeve Solid Hooded Sweatshirt
# 1               Men Full Sleeve Solid Hooded Sweatshirt
# 2     Men Regular Fit Printed Spread Collar Casual S...
# 3            Unstitched Polycotton Shirt Fabric Printed
# ...

# %%
data1.drop('Unnamed: 0.1',axis=1,inplace=True)

# %%
data1.drop('Unnamed: 0',axis=1,inplace=True)

# %%
data1
# Out:
#        sno     Brand_name                                           Category  \
# 0        0   Chanda Khuba            Men Full Sleeve Solid Hooded Sweatshirt
# 1        1   Chanda Khuba            Men Full Sleeve Solid Hooded Sweatshirt
# 2        2  Swear Clothes  Men Regular Fit Printed Spread Collar Casual S...
# 3        3  VALKO FASHION         Unstitched Polycotton Shirt Fabric Printed
# 4        4       PROTOCOL            Men Full Sleeve Solid Hooded Sweatshirt
# ...    ...            ...                                                ...
# 3995  3995      Indi Hemp    Men Slim Fit Solid Cut Away Collar Casual Shirt
# 3996  3996      Indi Hemp            Men Full Sleeve Solid Hooded Sweatshirt
# 3997  3997      Indi Hemp            Men Full Sleeve Solid Hooded Sweatshirt
# 3998  3998      Indi Hemp  Men Regular Fit Printed Spread Collar Casual S...
# 3999  3999      Indi Hemp         Unstitched Polycotton Shirt Fabric Printed
#
# ...

# %%
data2=pd.read_csv('https://raw.githubusercontent.com/12345mayanksingh/model11/main/Table_2.csv')
data2
# Out:
#       Unnamed: 0   sno         material_type  Reviews weartype color1 color2  \
# 0              0     0                   NaN      NaN  Topwear    Red  Black
# 1              1     1                   NaN      4.2  Topwear    Red  Black
# 2              2     2    Fabric\nPolycotton      4.2  Topwear    Red  Black
# 3              3     3                   NaN      3.6  Topwear    Red  Black
# 4              4     4                   NaN      NaN  Topwear    Red  Black
# ...          ...   ...                   ...      ...      ...    ...    ...
# 3995        3995  3995                   NaN      3.7  Topwear    Red  Black
# 3996        3996  3996  Fabric\nCotton Blend      NaN  Topwear    Red  Black
# 3997        3997  3997                   NaN      3.6  Topwear    Red  Black
# 3998        3998  3998                   NaN      3.9  Topwear    Red  Black
# 3999        3999  3999                   NaN      NaN  Topwear    Red  Black
#
#       color3  color4
# 0     Maroon     NaN
# ...

# %%
data2.drop('Unnamed: 0',axis=1,inplace=True)

# %%
data2
# Out:
#        sno         material_type  Reviews weartype color1 color2  color3  \
# 0        0                   NaN      NaN  Topwear    Red  Black  Maroon
# 1        1                   NaN      4.2  Topwear    Red  Black  Maroon
# 2        2    Fabric\nPolycotton      4.2  Topwear    Red  Black  Maroon
# 3        3                   NaN      3.6  Topwear    Red  Black  Maroon
# 4        4                   NaN      NaN  Topwear    Red  Black  Maroon
# ...    ...                   ...      ...      ...    ...    ...     ...
# 3995  3995                   NaN      3.7  Topwear    Red  Black  Maroon
# 3996  3996  Fabric\nCotton Blend      NaN  Topwear    Red  Black  Maroon
# 3997  3997                   NaN      3.6  Topwear    Red  Black  Maroon
# 3998  3998                   NaN      3.9  Topwear    Red  Black  Maroon
# 3999  3999                   NaN      NaN  Topwear    Red  Black  Maroon
#
#       color4
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...

# %%
data3=pd.read_csv('https://raw.githubusercontent.com/12345mayanksingh/model11/main/Table3.csv')
data3
# Out:
#       Unnamed: 0   sno             return_time country size size2 size3 size4  \
# 0              0     0  10 days return policy?   India    S     M     L    XL
# 1              1     1  10 days return policy?   India    S     M     L    XL
# 2              2     2  10 Days Return Policy?   India    S     M     L    XL
# 3              3     3                     NaN   India    S     M     L    XL
# 4              4     4  10 Days Return Policy?   India    S     M     L    XL
# ...          ...   ...                     ...     ...  ...   ...   ...   ...
# 3995        3995  3995  10 Days Return Policy?   India    S     M     L    XL
# 3996        3996  3996  10 Days Return Policy?   India    S     M     L    XL
# 3997        3997  3997  10 Days Return Policy?   India    S     M     L    XL
# 3998        3998  3998  10 Days Return Policy?   India    S     M     L    XL
# 3999        3999  3999  10 Days Return Policy?   India    S     M     L    XL
#
#       Occasion
# 0          NaN
# ...

# %%
data3.drop('Unnamed: 0',axis=1,inplace=True)

# %%
data3
# Out:
#        sno             return_time country size size2 size3 size4  Occasion
# 0        0  10 days return policy?   India    S     M     L    XL       NaN
# 1        1  10 days return policy?   India    S     M     L    XL       NaN
# 2        2  10 Days Return Policy?   India    S     M     L    XL       NaN
# 3        3                     NaN   India    S     M     L    XL       NaN
# 4        4  10 Days Return Policy?   India    S     M     L    XL       NaN
# ...    ...                     ...     ...  ...   ...   ...   ...       ...
# 3995  3995  10 Days Return Policy?   India    S     M     L    XL       NaN
# 3996  3996  10 Days Return Policy?   India    S     M     L    XL       NaN
# 3997  3997  10 Days Return Policy?   India    S     M     L    XL       NaN
# 3998  3998  10 Days Return Policy?   India    S     M     L    XL       NaN
# 3999  3999  10 Days Return Policy?   India    S     M     L    XL       NaN
#
# [4000 rows x 8 columns]

# %%
df=pd.merge(data1,data2, on='sno')

# %%
df
# Out:
#        sno     Brand_name                                           Category  \
# 0        0   Chanda Khuba            Men Full Sleeve Solid Hooded Sweatshirt
# 1        1   Chanda Khuba            Men Full Sleeve Solid Hooded Sweatshirt
# 2        2  Swear Clothes  Men Regular Fit Printed Spread Collar Casual S...
# 3        3  VALKO FASHION         Unstitched Polycotton Shirt Fabric Printed
# 4        4       PROTOCOL            Men Full Sleeve Solid Hooded Sweatshirt
# ...    ...            ...                                                ...
# 3995  3995      Indi Hemp    Men Slim Fit Solid Cut Away Collar Casual Shirt
# 3996  3996      Indi Hemp            Men Full Sleeve Solid Hooded Sweatshirt
# 3997  3997      Indi Hemp            Men Full Sleeve Solid Hooded Sweatshirt
# 3998  3998      Indi Hemp  Men Regular Fit Printed Spread Collar Casual S...
# 3999  3999      Indi Hemp         Unstitched Polycotton Shirt Fabric Printed
#
# ...

# %%
df1=pd.merge(df,data3,on='sno')

# %%
df1
# Out:
#        sno     Brand_name                                           Category  \
# 0        0   Chanda Khuba            Men Full Sleeve Solid Hooded Sweatshirt
# 1        1   Chanda Khuba            Men Full Sleeve Solid Hooded Sweatshirt
# 2        2  Swear Clothes  Men Regular Fit Printed Spread Collar Casual S...
# 3        3  VALKO FASHION         Unstitched Polycotton Shirt Fabric Printed
# 4        4       PROTOCOL            Men Full Sleeve Solid Hooded Sweatshirt
# ...    ...            ...                                                ...
# 3995  3995      Indi Hemp    Men Slim Fit Solid Cut Away Collar Casual Shirt
# 3996  3996      Indi Hemp            Men Full Sleeve Solid Hooded Sweatshirt
# 3997  3997      Indi Hemp            Men Full Sleeve Solid Hooded Sweatshirt
# 3998  3998      Indi Hemp  Men Regular Fit Printed Spread Collar Casual S...
# 3999  3999      Indi Hemp         Unstitched Polycotton Shirt Fabric Printed
#
# ...

# %%
#We used merge to combine all the three tables.
#we combine it into 1 dataframe name df1.
#Now we start EDA

# %%
df1
# Out:
#        sno     Brand_name                                           Category  \
# 0        0   Chanda Khuba            Men Full Sleeve Solid Hooded Sweatshirt
# 1        1   Chanda Khuba            Men Full Sleeve Solid Hooded Sweatshirt
# 2        2  Swear Clothes  Men Regular Fit Printed Spread Collar Casual S...
# 3        3  VALKO FASHION         Unstitched Polycotton Shirt Fabric Printed
# 4        4       PROTOCOL            Men Full Sleeve Solid Hooded Sweatshirt
# ...    ...            ...                                                ...
# 3995  3995      Indi Hemp    Men Slim Fit Solid Cut Away Collar Casual Shirt
# 3996  3996      Indi Hemp            Men Full Sleeve Solid Hooded Sweatshirt
# 3997  3997      Indi Hemp            Men Full Sleeve Solid Hooded Sweatshirt
# 3998  3998      Indi Hemp  Men Regular Fit Printed Spread Collar Casual S...
# 3999  3999      Indi Hemp         Unstitched Polycotton Shirt Fabric Printed
#
# ...

# %%
#In our dataframe there are total 4000 rows and 21 columns

# %%
#first we drop those columns which are completely null

# %%
df1.drop(['Product_code','color4','Occasion'],axis=1,inplace=True)

# %%
df1
# Out:
#        sno     Brand_name                                           Category  \
# 0        0   Chanda Khuba            Men Full Sleeve Solid Hooded Sweatshirt
# 1        1   Chanda Khuba            Men Full Sleeve Solid Hooded Sweatshirt
# 2        2  Swear Clothes  Men Regular Fit Printed Spread Collar Casual S...
# 3        3  VALKO FASHION         Unstitched Polycotton Shirt Fabric Printed
# 4        4       PROTOCOL            Men Full Sleeve Solid Hooded Sweatshirt
# ...    ...            ...                                                ...
# 3995  3995      Indi Hemp    Men Slim Fit Solid Cut Away Collar Casual Shirt
# 3996  3996      Indi Hemp            Men Full Sleeve Solid Hooded Sweatshirt
# 3997  3997      Indi Hemp            Men Full Sleeve Solid Hooded Sweatshirt
# 3998  3998      Indi Hemp  Men Regular Fit Printed Spread Collar Casual S...
# 3999  3999      Indi Hemp         Unstitched Polycotton Shirt Fabric Printed
#
# ...

# %%
#As all the products are made in India so we can drop this feature.

# %%
df1.drop('country',axis=1,inplace=True)

# %%
df1
# Out:
#        sno     Brand_name                                           Category  \
# 0        0   Chanda Khuba            Men Full Sleeve Solid Hooded Sweatshirt
# 1        1   Chanda Khuba            Men Full Sleeve Solid Hooded Sweatshirt
# 2        2  Swear Clothes  Men Regular Fit Printed Spread Collar Casual S...
# 3        3  VALKO FASHION         Unstitched Polycotton Shirt Fabric Printed
# 4        4       PROTOCOL            Men Full Sleeve Solid Hooded Sweatshirt
# ...    ...            ...                                                ...
# 3995  3995      Indi Hemp    Men Slim Fit Solid Cut Away Collar Casual Shirt
# 3996  3996      Indi Hemp            Men Full Sleeve Solid Hooded Sweatshirt
# 3997  3997      Indi Hemp            Men Full Sleeve Solid Hooded Sweatshirt
# 3998  3998      Indi Hemp  Men Regular Fit Printed Spread Collar Casual S...
# 3999  3999      Indi Hemp         Unstitched Polycotton Shirt Fabric Printed
#
# ...

# %%
#As column 'Product_type','category'and 'product_name' are all same so we can drop any 2 features

# %%
df1.drop(['Product_type','Product_name'],axis=1,inplace=True)

# %%
df1
# Out:
#        sno     Brand_name                                           Category  \
# 0        0   Chanda Khuba            Men Full Sleeve Solid Hooded Sweatshirt
# 1        1   Chanda Khuba            Men Full Sleeve Solid Hooded Sweatshirt
# 2        2  Swear Clothes  Men Regular Fit Printed Spread Collar Casual S...
# 3        3  VALKO FASHION         Unstitched Polycotton Shirt Fabric Printed
# 4        4       PROTOCOL            Men Full Sleeve Solid Hooded Sweatshirt
# ...    ...            ...                                                ...
# 3995  3995      Indi Hemp    Men Slim Fit Solid Cut Away Collar Casual Shirt
# 3996  3996      Indi Hemp            Men Full Sleeve Solid Hooded Sweatshirt
# 3997  3997      Indi Hemp            Men Full Sleeve Solid Hooded Sweatshirt
# 3998  3998      Indi Hemp  Men Regular Fit Printed Spread Collar Casual S...
# 3999  3999      Indi Hemp         Unstitched Polycotton Shirt Fabric Printed
#
# ...

# %%
#we can also drop sno

# %%
df1.drop('sno',axis=1,inplace=True)

# %%
df1
# Out:
#          Brand_name                                           Category  Price  \
# 0      Chanda Khuba            Men Full Sleeve Solid Hooded Sweatshirt  1,490
# 1      Chanda Khuba            Men Full Sleeve Solid Hooded Sweatshirt  1,490
# 2     Swear Clothes  Men Regular Fit Printed Spread Collar Casual S...    447
# 3     VALKO FASHION         Unstitched Polycotton Shirt Fabric Printed    299
# 4          PROTOCOL            Men Full Sleeve Solid Hooded Sweatshirt    299
# ...             ...                                                ...    ...
# 3995      Indi Hemp    Men Slim Fit Solid Cut Away Collar Casual Shirt    499
# 3996      Indi Hemp            Men Full Sleeve Solid Hooded Sweatshirt    994
# 3997      Indi Hemp            Men Full Sleeve Solid Hooded Sweatshirt    499
# 3998      Indi Hemp  Men Regular Fit Printed Spread Collar Casual S...    499
# 3999      Indi Hemp         Unstitched Polycotton Shirt Fabric Printed    499
#
# ...

# %%
#Now we can also delete  weartype because all our clothes are topwear

# %%
df1.drop('weartype',axis=1,inplace=True)

# %%
df1
# Out:
#          Brand_name                                           Category  Price  \
# 0      Chanda Khuba            Men Full Sleeve Solid Hooded Sweatshirt  1,490
# 1      Chanda Khuba            Men Full Sleeve Solid Hooded Sweatshirt  1,490
# 2     Swear Clothes  Men Regular Fit Printed Spread Collar Casual S...    447
# 3     VALKO FASHION         Unstitched Polycotton Shirt Fabric Printed    299
# 4          PROTOCOL            Men Full Sleeve Solid Hooded Sweatshirt    299
# ...             ...                                                ...    ...
# 3995      Indi Hemp    Men Slim Fit Solid Cut Away Collar Casual Shirt    499
# 3996      Indi Hemp            Men Full Sleeve Solid Hooded Sweatshirt    994
# 3997      Indi Hemp            Men Full Sleeve Solid Hooded Sweatshirt    499
# 3998      Indi Hemp  Men Regular Fit Printed Spread Collar Casual S...    499
# 3999      Indi Hemp         Unstitched Polycotton Shirt Fabric Printed    499
#
# ...

# %%
#The sizes are not impacting on prices so we can drop that columns

# %%
df1.drop(['size','size2','size3','size4'],axis=1,inplace=True)

# %%
df1
# Out:
#          Brand_name                                           Category  Price  \
# 0      Chanda Khuba            Men Full Sleeve Solid Hooded Sweatshirt  1,490
# 1      Chanda Khuba            Men Full Sleeve Solid Hooded Sweatshirt  1,490
# 2     Swear Clothes  Men Regular Fit Printed Spread Collar Casual S...    447
# 3     VALKO FASHION         Unstitched Polycotton Shirt Fabric Printed    299
# 4          PROTOCOL            Men Full Sleeve Solid Hooded Sweatshirt    299
# ...             ...                                                ...    ...
# 3995      Indi Hemp    Men Slim Fit Solid Cut Away Collar Casual Shirt    499
# 3996      Indi Hemp            Men Full Sleeve Solid Hooded Sweatshirt    994
# 3997      Indi Hemp            Men Full Sleeve Solid Hooded Sweatshirt    499
# 3998      Indi Hemp  Men Regular Fit Printed Spread Collar Casual S...    499
# 3999      Indi Hemp         Unstitched Polycotton Shirt Fabric Printed    499
#
# ...

# %%
#the colours are also not impacting on prices so we can also drop that columns

# %%
df1.drop(['color1','color2','color3'],axis=1,inplace=True)

# %%
df1
# Out:
#          Brand_name                                           Category  Price  \
# 0      Chanda Khuba            Men Full Sleeve Solid Hooded Sweatshirt  1,490
# 1      Chanda Khuba            Men Full Sleeve Solid Hooded Sweatshirt  1,490
# 2     Swear Clothes  Men Regular Fit Printed Spread Collar Casual S...    447
# 3     VALKO FASHION         Unstitched Polycotton Shirt Fabric Printed    299
# 4          PROTOCOL            Men Full Sleeve Solid Hooded Sweatshirt    299
# ...             ...                                                ...    ...
# 3995      Indi Hemp    Men Slim Fit Solid Cut Away Collar Casual Shirt    499
# 3996      Indi Hemp            Men Full Sleeve Solid Hooded Sweatshirt    994
# 3997      Indi Hemp            Men Full Sleeve Solid Hooded Sweatshirt    499
# 3998      Indi Hemp  Men Regular Fit Printed Spread Collar Casual S...    499
# 3999      Indi Hemp         Unstitched Polycotton Shirt Fabric Printed    499
#
# ...

# %%
#price is the label ,so except that now we will count every feature

# %%
for i in df1.columns:
    print(df1[i].value_counts())
    print('************************************************************************')
# Out:
# Brand_name
# Indi Hemp          2100
# Chanda Khuba        700
# VALKO FASHION       300
# Swear Clothes       200
# PROTOCOL            200
# Ik Fashion Town     200
# Force               100
# Lauren Adams        100
# JUHIL BAZAR         100
# Name: count, dtype: int64
# ************************************************************************
# Category
# Men Full Sleeve Solid Hooded Sweatshirt                       758
# Men Slim Fit Solid Cut Away Collar Casual Shirt               648
# Men Regular, Slim, Tailored Fit Solid Button Down Colla...    648
# Unstitched Polycotton Shirt Fabric Printed                    325
# Men Regular Fit Printed Spread Collar Casual Shirt            217
# Men Regular, Slim, Tailored Fit Printed Button Down Col...    216
# Men Slim Mid Rise Black Jeans                                 216
# Men Slim Fit Checkered Button Down Collar Casual Shirt        216
# trendy stylish design Shirt for men look new cotton uni...    108
# ...

# %%
#so we will use the encoding technique to covert the features

# %%
df1.isnull().sum()
# Out:
# Brand_name          0
# Category            0
# Price               0
# material_type    2304
# Reviews          2411
# return_time      2302
# dtype: int64

# %%
#As prices are divided into groups so we will do classification model

# %%
#Now we will drop nulls from material_type

# %%
#Every data has 10 days return time aur nulls so we will drop that feature

# %%
df1.drop('return_time',axis=1,inplace=True)

# %%
df1
# Out:
#          Brand_name                                           Category  Price  \
# 0      Chanda Khuba            Men Full Sleeve Solid Hooded Sweatshirt  1,490
# 1      Chanda Khuba            Men Full Sleeve Solid Hooded Sweatshirt  1,490
# 2     Swear Clothes  Men Regular Fit Printed Spread Collar Casual S...    447
# 3     VALKO FASHION         Unstitched Polycotton Shirt Fabric Printed    299
# 4          PROTOCOL            Men Full Sleeve Solid Hooded Sweatshirt    299
# ...             ...                                                ...    ...
# 3995      Indi Hemp    Men Slim Fit Solid Cut Away Collar Casual Shirt    499
# 3996      Indi Hemp            Men Full Sleeve Solid Hooded Sweatshirt    994
# 3997      Indi Hemp            Men Full Sleeve Solid Hooded Sweatshirt    499
# 3998      Indi Hemp  Men Regular Fit Printed Spread Collar Casual S...    499
# 3999      Indi Hemp         Unstitched Polycotton Shirt Fabric Printed    499
#
# ...

# %%
df1['Reviews'].fillna(value=df1['Reviews'].mode()[0],inplace=True)

# %%
df1
# Out:
#          Brand_name                                           Category  Price  \
# 0      Chanda Khuba            Men Full Sleeve Solid Hooded Sweatshirt  1,490
# 1      Chanda Khuba            Men Full Sleeve Solid Hooded Sweatshirt  1,490
# 2     Swear Clothes  Men Regular Fit Printed Spread Collar Casual S...    447
# 3     VALKO FASHION         Unstitched Polycotton Shirt Fabric Printed    299
# 4          PROTOCOL            Men Full Sleeve Solid Hooded Sweatshirt    299
# ...             ...                                                ...    ...
# 3995      Indi Hemp    Men Slim Fit Solid Cut Away Collar Casual Shirt    499
# 3996      Indi Hemp            Men Full Sleeve Solid Hooded Sweatshirt    994
# 3997      Indi Hemp            Men Full Sleeve Solid Hooded Sweatshirt    499
# 3998      Indi Hemp  Men Regular Fit Printed Spread Collar Casual S...    499
# 3999      Indi Hemp         Unstitched Polycotton Shirt Fabric Printed    499
#
# ...

# %%
df1.isnull().sum()
# Out:
# Brand_name          0
# Category            0
# Price               0
# material_type    2304
# Reviews             0
# dtype: int64

# %%
df1.dropna(axis=0,inplace=True)

# %%
df1
# Out:
#          Brand_name                                           Category Price  \
# 2     Swear Clothes  Men Regular Fit Printed Spread Collar Casual S...   447
# 5          PROTOCOL            Men Full Sleeve Solid Hooded Sweatshirt   319
# 9         Indi Hemp            Men Full Sleeve Solid Hooded Sweatshirt   499
# 12        Indi Hemp  Men Regular, Slim, Tailored Fit Solid Button D...   499
# 13        Indi Hemp  Men Regular, Slim, Tailored Fit Printed Button...   499
# ...             ...                                                ...   ...
# 3990      Indi Hemp    Men Slim Fit Solid Cut Away Collar Casual Shirt   499
# 3991  VALKO FASHION    Men Slim Fit Solid Cut Away Collar Casual Shirt   299
# 3993      Indi Hemp    Men Slim Fit Solid Cut Away Collar Casual Shirt   499
# 3994      Indi Hemp  Men Regular, Slim, Tailored Fit Solid Button D...   499
# 3996      Indi Hemp            Men Full Sleeve Solid Hooded Sweatshirt   994
#
# ...

# %%
df1=df1.reset_index()

# %%
df1.drop('index',axis=1,inplace=True)

# %%
df2=df1

# %%
#now we use encoding techniques

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lab_enc=LabelEncoder()

# %%
df3=lab_enc.fit_transform(df1['Brand_name'])

# %%
pd.Series(df3)
# Out:
# 0       4
# 1       3
# 2       1
# 3       1
# 4       1
#        ..
# 1691    1
# 1692    5
# 1693    1
# 1694    1
# 1695    1
# Length: 1696, dtype: int32

# %%
df1['Brand_name']=df3

# %%
df1
# Out:
#       Brand_name                                           Category Price  \
# 0              4  Men Regular Fit Printed Spread Collar Casual S...   447
# 1              3            Men Full Sleeve Solid Hooded Sweatshirt   319
# 2              1            Men Full Sleeve Solid Hooded Sweatshirt   499
# 3              1  Men Regular, Slim, Tailored Fit Solid Button D...   499
# 4              1  Men Regular, Slim, Tailored Fit Printed Button...   499
# ...          ...                                                ...   ...
# 1691           1    Men Slim Fit Solid Cut Away Collar Casual Shirt   499
# 1692           5    Men Slim Fit Solid Cut Away Collar Casual Shirt   299
# 1693           1    Men Slim Fit Solid Cut Away Collar Casual Shirt   499
# 1694           1  Men Regular, Slim, Tailored Fit Solid Button D...   499
# 1695           1            Men Full Sleeve Solid Hooded Sweatshirt   994
#
#                                           material_type  Reviews
# ...

# %%
df4=lab_enc.fit_transform(df1['Category'])

# %%
pd.Series(df4)
# Out:
# 0        1
# 1        0
# 2        0
# 3        5
# 4        4
#         ..
# 1691    10
# 1692    10
# 1693    10
# 1694     5
# 1695     0
# Length: 1696, dtype: int32

# %%
df1['Category']=df4

# %%
df1
# Out:
#       Brand_name  Category Price  \
# 0              4         1   447
# 1              3         0   319
# 2              1         0   499
# 3              1         5   499
# 4              1         4   499
# ...          ...       ...   ...
# 1691           1        10   499
# 1692           5        10   299
# 1693           1        10   499
# 1694           1         5   499
# 1695           1         0   994
#
#                                           material_type  Reviews
# 0                                    Fabric\nPolycotton      4.2
# 1                                   Sleeve\nFull Sleeve      3.7
# 2                                   Sleeve\nFull Sleeve      4.2
# 3                                   Sleeve\nFull Sleeve      3.6
# 4                                  Fabric\nCotton Blend      3.9
# ...                                                 ...      ...
# 1691                                Sleeve\nFull Sleeve      4.2
# ...

# %%
df5=lab_enc.fit_transform(df1['Price'])

# %%
pd.Series(df5)
# Out:
# 0       4
# 1       1
# 2       5
# 3       5
# 4       5
#        ..
# 1691    5
# 1692    0
# 1693    5
# 1694    5
# 1695    6
# Length: 1696, dtype: int32

# %%
df1['Price']=df5

# %%
df6=lab_enc.fit_transform(df1['material_type'])

# %%
pd.Series(df6)
# Out:
# 0       1
# 1       4
# 2       4
# 3       4
# 4       0
#        ..
# 1691    4
# 1692    2
# 1693    4
# 1694    0
# 1695    0
# Length: 1696, dtype: int32

# %%
df1['material_type']=df6

# %%
df7=lab_enc.fit_transform(df1['Reviews'])

# %%
pd.Series(df7)
# Out:
# 0       5
# 1       1
# 2       5
# 3       0
# 4       2
#        ..
# 1691    5
# 1692    5
# 1693    4
# 1694    3
# 1695    5
# Length: 1696, dtype: int64

# %%
df1['Reviews']=df7

# %%
df1
# Out:
#       Brand_name  Category  Price  material_type  Reviews
# 0              4         1      4              1        5
# 1              3         0      1              4        1
# 2              1         0      5              4        5
# 3              1         5      5              4        0
# 4              1         4      5              0        2
# ...          ...       ...    ...            ...      ...
# 1691           1        10      5              4        5
# 1692           5        10      0              2        5
# 1693           1        10      5              4        4
# 1694           1         5      5              0        3
# 1695           1         0      6              0        5
#
# [1696 rows x 5 columns]

# %%
#Now we have changed all the data using Label Encoder Technique

# %%
#As all the features are categorical so we will not check for outliers nor for skewness

# %%
plt.figure(figsize=(10,12),facecolor='Red')
plotnumber=1
for colo in df1:
    if plotnumber<=7:
        ax=plt.subplot(2,3,plotnumber)
        sns.distplot(df1[colo],color='b')
        plt.xlabel(colo,fontsize=12)
    plotnumber+=1
plt.show()

# %%
df1.corr()
# Out:
#                Brand_name  Category     Price  material_type   Reviews
# Brand_name       1.000000 -0.003473 -0.032668       0.145267  0.101295
# Category        -0.003473  1.000000 -0.009072       0.000559  0.004055
# Price           -0.032668 -0.009072  1.000000      -0.142199  0.153472
# material_type    0.145267  0.000559 -0.142199       1.000000 -0.020341
# Reviews          0.101295  0.004055  0.153472      -0.020341  1.000000

# %%
plt.figure(figsize=(30,12))
sns.heatmap(df1.describe(),linewidths = 0.1,fmt='0.1f',annot = True,cmap='PiYG')
# Out:
# <Axes: >

# %%
#Now we cannot drop further more columns

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df1)
plt.show()

# %%
#Now we will split features and label and do the standard scaling

# %%
x=df1.drop('Price',axis=1)
y=df1['Price']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)
x_scaled
# Out:
# array([[ 1.37338329e+00, -1.15556341e+00, -6.83237177e-01,
#          6.47962987e-01],
#        [ 1.03426641e+00, -1.37789303e+00,  1.05665810e+00,
#         -1.81742170e+00],
#        [ 1.04033248e-03, -1.37789303e+00,  1.05665810e+00,
#          6.47962987e-01],
#        ...,
#        [ 1.04033248e-03,  8.45403115e-01,  1.05665810e+00,
#          3.16168143e-02],
#        [ 1.04033248e-03, -2.66244957e-01, -1.26320227e+00,
#         -5.84729359e-01],
#        [ 1.04033248e-03, -1.37789303e+00, -1.26320227e+00,
#          6.47962987e-01]])

# %%
#Now we will check for VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif["Vif"]=[variance_inflation_factor(x_scaled,i) for i in range(x_scaled.shape[1])]
vif["Features"]=x.columns

# %%
vif
# Out:
#         Vif       Features
# 0  1.033048     Brand_name
# 1  1.000033       Category
# 2  1.022856  material_type
# 3  1.011671        Reviews

# %%
#As all the values are less than 5 that means there is no multicollinearity

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,random_state=22,test_size=0.25)

# %% [markdown]
# # Model_Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import BaggingClassifier

# %%
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, random_state=99, test_size=.3)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (1187, 4)
# Training target vector size: (1187,)
# Test feature matrix size: (509, 4)
# Test target vector size: (509,)

# %%
#Finding best state

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score
maxAccu=0
maxRS=0
for i in range(1,250):
    x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size = 0.3, random_state=i)
    log_reg=LogisticRegression()
    log_reg.fit(x_train,y_train)
    y_pred=log_reg.predict(x_test)
    acc=accuracy_score(y_test,y_pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Best accuracy is', maxAccu ,'on Random_state', maxRS)
# Out:
# Best accuracy is 0.9607072691552063 on Random_state 191

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x_scaled, y, random_state=191, test_size=.3)
log_reg=LogisticRegression()
log_reg.fit(x_train,y_train)
y_pred=log_reg.predict(x_test)
print('\033[1m'+'Logistics Regression Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Logistics Regression :'+'\033[0m', accuracy_score(y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Logistics Regression :'+'\033[0m \n',confusion_matrix(y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Logistics Regression'+'\033[0m \n',classification_report(y_test, y_pred))
# Out:
# Logistics Regression Evaluation
#
#
# Accuracy Score of Logistics Regression : 0.93713163064833
#
#
# Confusion matrix of Logistics Regression :
#  [[ 30   0   0   0   0   0   0]
#  [  0  35   0   0   0   0   0]
#  [  0   0  66   0   0   0   0]
#  [  0   0   0  26   0   0   0]
#  [  0   0   0   0  24   0   0]
#  [  0   0   0   0   0 296   0]
#  [  0   0   0   0   0  32   0]]
#
#
# classification Report of Logistics Regression
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        30
#            1       1.00      1.00      1.00        35
#            2       1.00      1.00      1.00        66
#            3       1.00      1.00      1.00        26
#            4       1.00      1.00      1.00        24
#            5       0.90      1.00      0.95       296
#            6       0.00      0.00      0.00        32
#
#     accuracy                           0.94       509
#    macro avg       0.84      0.86      0.85       509
# ...

# %%
#Find knn

# %%
from sklearn import neighbors
from math import sqrt
from sklearn.metrics import mean_squared_error
rmse_val = [] #to store rmse values for different k
for K in range(12):
    K = K+1
    model = neighbors.KNeighborsClassifier(n_neighbors = K)

    model.fit(X_train,Y_train)  #fit the model
    y_pred=model.predict(X_test) #make prediction on test set
    error = sqrt(mean_squared_error(Y_test,y_pred)) #calculate rmse
    rmse_val.append(error) #store rmse values
    print('RMSE value for k= ' , K , 'is:', error)
# Out:
# RMSE value for k=  1 is: 0.21714344801018623
# RMSE value for k=  2 is: 0.20311909655921917
# RMSE value for k=  3 is: 0.2386932335131243
# RMSE value for k=  4 is: 0.24277375530973394
# RMSE value for k=  5 is: 0.2507356563228891
# RMSE value for k=  6 is: 0.2507356563228891
# RMSE value for k=  7 is: 0.24678681652274348
# RMSE value for k=  8 is: 0.2260100663648233
# RMSE value for k=  9 is: 0.2125714949646654
# RMSE value for k=  10 is: 0.20311909655921917
# RMSE value for k=  11 is: 0.20311909655921917
# RMSE value for k=  12 is: 0.20311909655921917

# %%
#Applying other Algorithms

# %%
model=[ LogisticRegression(),
        SVC(),
        GaussianNB(),
        DecisionTreeClassifier(),
        KNeighborsClassifier(n_neighbors = 3),
        RandomForestClassifier(),
        ExtraTreesClassifier()]
        
for m in model:
    m.fit(x_train,y_train)
    y_pred=m.predict(x_test)
    print('\033[1m'+'Classification ML Algorithm Evaluation Matrix',m,'is' +'\033[0m')
    print('\n')
    print('\033[1m'+'Accuracy Score :'+'\033[0m\n', accuracy_score(y_test, y_pred))
    print('\n')
    print('\033[1m'+'Confusion matrix :'+'\033[0m \n',confusion_matrix(y_test, y_pred))
    print('\n')
    print('\033[1m'+'Classification Report :'+'\033[0m \n',classification_report(y_test, y_pred))
    print('\n')
    print('====================================================================================================')
# Out:
# Classification ML Algorithm Evaluation Matrix LogisticRegression() is
#
#
# Accuracy Score :
#  0.93713163064833
#
#
# Confusion matrix :
#  [[ 30   0   0   0   0   0   0]
#  [  0  35   0   0   0   0   0]
#  [  0   0  66   0   0   0   0]
#  [  0   0   0  26   0   0   0]
#  [  0   0   0   0  24   0   0]
#  [  0   0   0   0   0 296   0]
#  [  0   0   0   0   0  32   0]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        30
#            1       1.00      1.00      1.00        35
#            2       1.00      1.00      1.00        66
#            3       1.00      1.00      1.00        26
#            4       1.00      1.00      1.00        24
#            5       0.90      1.00      0.95       296
#            6       0.00      0.00      0.00        32
#
#     accuracy                           0.94       509
#    macro avg       0.84      0.86      0.85       509
# ...

# %%
from sklearn.model_selection import cross_val_score
model=[LogisticRegression(),
        SVC(),
        GaussianNB(),
        DecisionTreeClassifier(),
        KNeighborsClassifier(n_neighbors = 3),
        RandomForestClassifier(),
        ExtraTreesClassifier()]

for m in model:
    score = cross_val_score(m, x_scaled, y, cv =5)
    print('\n')
    print('\033[1m'+'Cross Validation Score', m, ':'+'\033[0m\n')
    print("Score :" ,score)
    print("Mean Score :",score.mean())
    print("Std deviation :",score.std())
    print('\n')
    print('===============================================================================')
# Out:
# Cross Validation Score LogisticRegression() :
#
# Score : [0.94117647 0.9380531  0.94100295 0.94100295 0.94100295]
# Mean Score : 0.9404476834981781
# Std deviation : 0.001199177688229788
#
#
# ...
#
#
# Cross Validation Score SVC() :
#
# Score : [0.94117647 0.94100295 0.94100295 0.94100295 0.94100295]
# Mean Score : 0.9410376539996529
# Std deviation : 6.940829429118445e-05
#
#
# ...
#
#
# Cross Validation Score GaussianNB() :
#
# Score : [0.94117647 0.94100295 0.9380531  0.94100295 0.9380531 ]
# Mean Score : 0.9398577129967031
# Std deviation : 0.001474824179134159
#
#
# ...
#
#
# Cross Validation Score DecisionTreeClassifier() :
#
# Score : [0.93235294 0.92035398 0.93510324 0.92920354 0.94100295]
# Mean Score : 0.9316033315981258
# Std deviation : 0.006833315311153939
#
#
# ...
#
#
# Cross Validation Score KNeighborsClassifier(n_neighbors=3) :
#
# Score : [0.93235294 0.92330383 0.94690265 0.93215339 0.94985251]
# Mean Score : 0.9369130661114002
# Std deviation : 0.009958729178986499
#
#
# ...
#
#
# ...

# %% [markdown]
# # Hyper parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter= {'criterion' : ['gini', 'entropy'],
              'min_samples_split':[3,5,8],
              'max_depth' : [20,30,40],
              'n_estimators' : [100, 150, 200]
             }

# %%
GCV = GridSearchCV(ExtraTreesClassifier(),parameter,verbose=10)
GCV.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV 1/5; 1/54] START criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100
# [CV 1/5; 1/54] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100;, score=0.929 total time=   0.1s
# [CV 2/5; 1/54] START criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100
# [CV 2/5; 1/54] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100;, score=0.912 total time=   0.0s
# [CV 3/5; 1/54] START criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100
# [CV 3/5; 1/54] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100;, score=0.924 total time=   0.1s
# [CV 4/5; 1/54] START criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100
# [CV 4/5; 1/54] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100;, score=0.932 total time=   0.0s
# ...

# %%
GCV.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 20,
#  'min_samples_split': 3,
#  'n_estimators': 100}

# %% [markdown]
# # Final_Model

# %%
Final_mod = ExtraTreesClassifier(criterion='gini',n_estimators= 100, max_depth=20 ,min_samples_split= 20)
Final_mod.fit(x_train,y_train)
y_pred=Final_mod.predict(x_test)
print('\033[1m'+'Accuracy Score :'+'\033[0m\n', accuracy_score(y_test, y_pred))
# Out:
# Accuracy Score :
#  0.925343811394892

# %%
Final_Model accuracy-92.5% Good accuracy

# %%
#We choose this algorithm because it makes the trees diversified and uncorrelated

# %%
import joblib
joblib.dump(Final_mod,'Flipkart_clothes')
# Out:
# ['Flipkart_clothes']
